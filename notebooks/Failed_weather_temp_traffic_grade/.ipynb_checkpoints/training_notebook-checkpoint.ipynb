# %% [markdown]
# ## Create a Model to find the best spot for my skate session

# %% [markdown]
# ##  TensorBoard settings:

# %%
! rm -rf ./logs/
! %load_ext tensorboard

# %% [markdown]
# My goal for this project is to build the best machine learning model to help me find the best skatepark for my session, according of the week day, the weather, temperature and the traffic time.
# Montréal has 14 skateparks, sometimes it's hard for me to choose the best spot.
# The input will be:
#  -  the weather (of course, I don't want to skate outside if it snows...)
#  -  the temperature
#  -  the traffic time (Sometimes the traffic at Montréal is a nightmare)
#  - I also gave a general grade for the skatepark..
#
# ## Connexion to the S3 bucket and get the data:

# %%
import os, boto3, random
import pandas as pd
from botocore.exceptions import ClientError
from io import StringIO
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, models
# Out:
# 2025-11-07 01:27:56.799417: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-07 01:27:56.799855: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-07 01:27:56.853465: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-07 01:27:58.031561: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-07 01:27:58.031997: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.

# %% [markdown]
# ## Get Data from S3:

# %% [markdown]
# For the model, as it's a simple regression, we can just give as a input 1 spot index, and not the 14 skatespots.
# The time to do all the inference will not be a problem, it's not a critical system.
# It will be easier to me to add skateparks, Montreal build new one, in the future.

# %%
s3 = boto3.client(
    "s3",
    endpoint_url=os.getenv("S3_ENDPOINT"),
    aws_access_key_id=os.getenv("AWS_ACCESS_KEY_ID"),
    aws_secret_access_key=os.getenv("AWS_SECRET_ACCESS_KEY"),
    region_name="us-east-1"
)

# %%
BUCKET_NAME = "skatedata"          # ton bucket
FILE_KEY = "skatepark_dataset_test.csv"  # ton fichier CSV

obj = s3.get_object(Bucket=BUCKET_NAME, Key=FILE_KEY)
df = pd.read_csv(StringIO(obj['Body'].read().decode('utf-8')))

print(df.head())
# Out:
#      spot_name  index spot  weather  temperature  traffic_time  weekday  \
# 0     Ahuntsic           0        3         15.8           5.0        1
# 1     VanHorne           1        3         15.8           5.0        1
# 2       Verdun           2        3         15.8           5.0        1
# 3      Lasalle           3        3         15.8           5.0        1
# 4  Préfontaine           4        3         15.8           5.0        1
#
#    park_score  satisfaction
# 0         8.0           9.0
# 1         4.0           2.0
# 2         2.0           1.0
# 3         8.5           9.0
# 4         8.5           8.0

# %% [markdown]
# ## Generator:

# %%
random.seed(1)

INPUTS_COLS = ["weather", "temperature", "traffic_time", "weekday", "park_score"]
OUTPUT_COL =  "satisfaction"
TRAINING_PERCENTAGE = 90



dataset = [
                [row[INPUTS_COLS].tolist(), row[OUTPUT_COL]]
                for _, row in df.iterrows()
            ]
random.shuffle(dataset)

split_idx = int(TRAINING_PERCENTAGE / 100 * len(dataset))
train_dataset = dataset[:split_idx]
val_dataset = dataset[split_idx:]


import numpy as np

def generator(part_dataset, batch_size=4):
    X_batch, y_batch = [], []

    while True:
        for X, y in part_dataset:
            X_batch.append(X)
            y_batch.append(y)

            if len(X_batch) == batch_size:
                yield np.array(X_batch, dtype=np.float32), np.array(y_batch, dtype=np.float32)
                X_batch, y_batch = [], []

        if X_batch:
            yield np.array(X_batch, dtype=np.float32), np.array(y_batch, dtype=np.float32)
            X_batch, y_batch = [], []

# %% [markdown]
# ## Model Architecture:

# %% [markdown]
# First Model tested will be 5 Dense Layers.

# %%
INPUT_DIM = 5
OUTPUT_DIM = 1

model = models.Sequential([
    layers.Input(shape = (INPUT_DIM,)),
    layers.Dense(64, activation='relu'),
    layers.Dense(64, activation='relu'),
    layers.Dense(32, activation='relu'),
    layers.Dense(OUTPUT_DIM, activation='linear')
])

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),
    loss='mse',            
    metrics=['mae']        
)

model.summary()
# Out:
# 2025-11-07 01:28:04.226159: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │           384 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,657 (26.00 KB)
#  Trainable params: 6,657 (26.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Training:

# %%
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

# %%
EPOCHS = 300
BATCHSIZE = 4

training_gen   = generator(train_dataset, BATCHSIZE)
validation_gen = generator(val_dataset, BATCHSIZE)

steps_per_epoch = len(train_dataset) // BATCHSIZE
validation_steps = len(val_dataset) // BATCHSIZE

history = model.fit(
    training_gen,
    validation_data=validation_gen,
    steps_per_epoch=steps_per_epoch,
    validation_steps=validation_steps,
    epochs=EPOCHS,
    callbacks = [tensorboard_callback]
)
# Out:
# Epoch 1/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 12.6057 - mae: 2.5650 - val_loss: 14.3281 - val_mae: 2.7765
# Epoch 2/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 11.1629 - mae: 2.5544 - val_loss: 16.8931 - val_mae: 3.2754
# Epoch 3/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 10.2814 - mae: 2.5718 - val_loss: 15.4393 - val_mae: 3.1308
# Epoch 4/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.6253 - mae: 2.5699 - val_loss: 13.3706 - val_mae: 3.0383
# Epoch 5/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5534 - mae: 2.6133 - val_loss: 10.6565 - val_mae: 2.6642
# Epoch 6/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.3209 - mae: 2.6096 - val_loss: 14.6957 - val_mae: 3.1551
# Epoch 7/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.1344 - mae: 2.6146 - val_loss: 14.6416 - val_mae: 3.1810
# Epoch 8/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.1845 - mae: 2.6279 - val_loss: 13.9441 - val_mae: 3.1476
# Epoch 9/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.1876 - mae: 2.6396 - val_loss: 9.9046 - val_mae: 2.6930
# Epoch 10/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.1136 - mae: 2.6382 - val_loss: 11.2826 - val_mae: 2.7548
# Epoch 11/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.9367 - mae: 2.6149 - val_loss: 14.0705 - val_mae: 3.1549
# Epoch 12/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.9289 - mae: 2.6159 - val_loss: 14.0718 - val_mae: 3.1782
# Epoch 13/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.9140 - mae: 2.6169 - val_loss: 12.5280 - val_mae: 3.0809
# Epoch 14/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.9136 - mae: 2.6254 - val_loss: 10.0177 - val_mae: 2.6709
# Epoch 15/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.8569 - mae: 2.6135 - val_loss: 13.8282 - val_mae: 3.0910
# Epoch 16/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.6919 - mae: 2.5984 - val_loss: 14.0522 - val_mae: 3.1462
# Epoch 17/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.7573 - mae: 2.6048 - val_loss: 13.6121 - val_mae: 3.1463
# Epoch 18/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.7498 - mae: 2.6035 - val_loss: 12.4412 - val_mae: 3.0816
# Epoch 19/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.6527 - mae: 2.5918 - val_loss: 9.9199 - val_mae: 2.6645
# Epoch 20/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.6532 - mae: 2.5913 - val_loss: 13.6789 - val_mae: 3.0733
# Epoch 21/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.6540 - mae: 2.5913 - val_loss: 13.9573 - val_mae: 3.1331
# Epoch 22/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.5894 - mae: 2.5792 - val_loss: 13.5798 - val_mae: 3.1423
# Epoch 23/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.5397 - mae: 2.5746 - val_loss: 9.5677 - val_mae: 2.6748
# Epoch 24/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.5059 - mae: 2.5690 - val_loss: 10.7757 - val_mae: 2.7032
# Epoch 25/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.4780 - mae: 2.5627 - val_loss: 13.6334 - val_mae: 3.1040
# Epoch 26/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.3316 - mae: 2.5483 - val_loss: 13.8770 - val_mae: 3.1677
# Epoch 27/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.3950 - mae: 2.5520 - val_loss: 12.4427 - val_mae: 3.0948
# Epoch 28/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.
300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.2124 - mae: 2.3215 - val_loss: 12.4575 - val_mae: 3.0313
# Epoch 194/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.2750 - mae: 2.3338 - val_loss: 8.8780 - val_mae: 2.5716
# Epoch 195/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.2129 - mae: 2.3239 - val_loss: 9.2552 - val_mae: 2.5148
# Epoch 196/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.2894 - mae: 2.3387 - val_loss: 11.9861 - val_mae: 2.8908
# Epoch 197/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.1182 - mae: 2.3092 - val_loss: 12.8471 - val_mae: 3.0459
# Epoch 198/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.2017 - mae: 2.3249 - val_loss: 11.7637 - val_mae: 3.0138
# Epoch 199/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.2121 - mae: 2.3197 - val_loss: 9.0490 - val_mae: 2.5395
# Epoch 200/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.2849 - mae: 2.3385 - val_loss: 11.7303 - val_mae: 2.8412
# Epoch 201/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.2216 - mae: 2.3232 - val_loss: 12.5029 - val_mae: 2.9390
# Epoch 202/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.2685 - mae: 2.3349 - val_loss: 12.3950 - val_mae: 3.0271
# Epoch 203/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.2351 - mae: 2.3241 - val_loss: 8.8436 - val_mae: 2.5701
# Epoch 204/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.1309 - mae: 2.3063 - val_loss: 9.1950 - val_mae: 2.5105
# Epoch 205/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.2357 - mae: 2.3232 - val_loss: 11.8802 - val_mae: 2.8808
# Epoch 206/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.2281 - mae: 2.3239 - val_loss: 12.7537 - val_mae: 3.0407
# Epoch 207/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.2398 - mae: 2.3276 - val_loss: 11.6916 - val_mae: 3.0114
# Epoch 208/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.2119 - mae: 2.3203 - val_loss: 8.9834 - val_mae: 2.5369
# Epoch 209/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.1453 - mae: 2.3043 - val_loss: 9.1532 - val_mae: 2.5083
# Epoch 210/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.2033 - mae: 2.3162 - val_loss: 11.8033 - val_mae: 2.8737
# Epoch 211/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.1010 - mae: 2.3044 - val_loss: 12.6950 - val_mae: 3.0374
# Epoch 212/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.2042 - mae: 2.3173 - val_loss: 11.6495 - val_mae: 3.0097
# Epoch 213/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.1799 - mae: 2.3124 - val_loss: 8.9583 - val_mae: 2.5352
# Epoch 214/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.1182 - mae: 2.3038 - val_loss: 11.5542 - val_mae: 2.8251
# Epoch 215/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.1280 - mae: 2.3057 - val_loss: 12.3394 - val_mae: 2.9250
# Epoch 216/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.2088 - mae: 2.3202 - val_loss: 12.2863 - val_mae: 3.0212
# Epoch 217/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.0591 - mae: 2.2940 - val_loss: 8.7948 - val_mae: 2.5680
# Epoch 218/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.1559 - mae: 2.3064 - val_loss: 9.1110 - val_mae: 2.5038
# Epoch 219/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.1167 - mae: 2.3021 - val_loss: 11.7487 - val_mae: 2.8671
# Epoch 220/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.1883 - mae: 2.3144 - val_loss: 12.6437 - val_mae: 3.0310
# Epoch 221/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.1935 - mae: 2.3147 - val_loss: 11.6155 - val_mae: 3.0049
# Epoch 222/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.1004 - mae: 2.2981 - val_loss: 8.9295 - val_mae: 2.5313
# Epoch 223/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.1458 - mae: 2.3079 - val_loss: 11.4972 - val_mae: 2.8186
# Epoch 224/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.1432 - mae: 2.3019 - val_loss: 12.2806 - val_mae: 2.9180
# Epoch 225/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.1684 - mae: 2.3090 - val_loss: 12.2411 - val_mae: 3.0159
# Epoch 226/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.
300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.9915 - mae: 2.2685 - val_loss: 11.5626 - val_mae: 2.8197
# Epoch 260/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.8817 - mae: 2.2548 - val_loss: 12.3771 - val_mae: 2.9123
# Epoch 261/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.8684 - mae: 2.2513 - val_loss: 12.2459 - val_mae: 2.9882
# Epoch 262/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.0353 - mae: 2.2763 - val_loss: 8.7818 - val_mae: 2.5458
# Epoch 263/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.9167 - mae: 2.2582 - val_loss: 9.0427 - val_mae: 2.4868
# Epoch 264/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.0078 - mae: 2.2702 - val_loss: 11.7764 - val_mae: 2.8642
# Epoch 265/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.9711 - mae: 2.2692 - val_loss: 12.6253 - val_mae: 3.0002
# Epoch 266/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.9093 - mae: 2.2590 - val_loss: 11.6221 - val_mae: 2.9762
# Epoch 267/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.0220 - mae: 2.2746 - val_loss: 8.9077 - val_mae: 2.5095
# Epoch 268/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.0107 - mae: 2.2716 - val_loss: 11.4925 - val_mae: 2.8137
# Epoch 269/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.9700 - mae: 2.2655 - val_loss: 12.3019 - val_mae: 2.9065
# Epoch 270/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.0222 - mae: 2.2779 - val_loss: 12.1954 - val_mae: 2.9844
# Epoch 271/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.9369 - mae: 2.2584 - val_loss: 8.7538 - val_mae: 2.5436
# Epoch 272/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.9947 - mae: 2.2702 - val_loss: 8.9992 - val_mae: 2.4842
# Epoch 273/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.9237 - mae: 2.2590 - val_loss: 11.7176 - val_mae: 2.8590
# Epoch 274/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.0057 - mae: 2.2734 - val_loss: 12.5818 - val_mae: 2.9973
# Epoch 275/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.8559 - mae: 2.2477 - val_loss: 11.5965 - val_mae: 2.9730
# Epoch 276/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.9120 - mae: 2.2596 - val_loss: 8.8845 - val_mae: 2.5085
# Epoch 277/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.9320 - mae: 2.2559 - val_loss: 11.4397 - val_mae: 2.8091
# Epoch 278/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.0026 - mae: 2.2752 - val_loss: 12.2433 - val_mae: 2.9022
# Epoch 279/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.9439 - mae: 2.2610 - val_loss: 12.1456 - val_mae: 2.9807
# Epoch 280/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.9912 - mae: 2.2729 - val_loss: 8.7241 - val_mae: 2.5426
# Epoch 281/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.9564 - mae: 2.2608 - val_loss: 8.9484 - val_mae: 2.4823
# Epoch 282/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.8611 - mae: 2.2447 - val_loss: 11.6233 - val_mae: 2.8516
# Epoch 283/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.9598 - mae: 2.2618 - val_loss: 12.4980 - val_mae: 2.9961
# Epoch 284/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.9522 - mae: 2.2623 - val_loss: 11.5266 - val_mae: 2.9718
# Epoch 285/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.9607 - mae: 2.2663 - val_loss: 8.8237 - val_mae: 2.5100
# Epoch 286/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.9334 - mae: 2.2570 - val_loss: 11.3099 - val_mae: 2.7997
# Epoch 287/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.8617 - mae: 2.2412 - val_loss: 12.1017 - val_mae: 2.8943
# Epoch 288/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.9223 - mae: 2.2537 - val_loss: 12.0557 - val_mae: 2.9789
# Epoch 289/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.8343 - mae: 2.2433 - val_loss: 8.6814 - val_mae: 2.5430
# Epoch 290/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.9333 - mae: 2.2569 - val_loss: 8.8906 - val_mae: 2.4816
# Epoch 291/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.9129 - mae: 2.2526 - val_loss: 11.5238 - val_mae: 2.8447
# Epoch 292/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.8460 - mae: 2.2420 - val_loss: 12.4193 - val_mae: 2.9939
# Epoch 293/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.8490 - mae: 2.2442 - val_loss: 11.4762 - val_mae: 2.9687
# Epoch 294/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.9370 - mae: 2.2592 - val_loss: 8.7876 - val_mae: 2.5092
# Epoch 295/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.7803 - mae: 2.2321 - val_loss: 11.2561 - val_mae: 2.7959
# Epoch 296/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.8804 - mae: 2.2449 - val_loss: 12.0599 - val_mae: 2.8912
# Epoch 297/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.8394 - mae: 2.2406 - val_loss: 12.0152 - val_mae: 2.9739
# Epoch 298/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.9164 - mae: 2.2535 - val_loss: 8.6630 - val_mae: 2.5404
# Epoch 299/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.9220 - mae: 2.2540 - val_loss: 8.8635 - val_mae: 2.4797
# Epoch 300/300
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.8322 - mae: 2.2385 - val_loss: 11.4899 - val_mae: 2.8418

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

mae = history.history.get('mae')
val_mae = history.history.get('val_mae')

epochs = range(1, EPOCHS + 1)

plt.figure(figsize = (12,5))
plt.subplot(1,2,1)
plt.plot(epochs, loss, 'bo-', label = "Training loss")
plt.plot(epochs, val_loss, 'ro-', label = "Val loss")

plt.title("Loss evolution")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()

plt.subplot(1,2,2)
plt.plot(epochs, mae, 'bo-', label='Training mae')
plt.plot(epochs, val_mae, 'ro-', label="Validation mae")
plt.title( "mae evolution")
plt.xlabel('Epochs')
plt.ylabel("mae")
plt.legend()
plt.show()

# %% [markdown]
# #### Observation:
# The Training Loss Seems to converge but there are oscillation in both val loss and val mae.
# This can be lead by a dataset which is noisy and also some irrelevant inputs such as grade for skatepark.
# Why a 9/10 skatepark with a Cloudy weather get less or more than a 8/10 skatepark with a Blue sky. After working on this, I will feed to make a relevant dataset with fewer inputs but relevant.

# %% [markdown]
# ## Test and Validation:

# %%
skateparks_dict = {
    "Ahuntsic": 8,
    "VanHorne": 4,
    "Verdun": 2,
    "Lasalle": 8.5,
    "Préfontaine": 8.5,
    "Boucherville": 7,
    "Taz": 7,
    "Spin": 6.5,
    "Saint Jérome": 8,
    "Saint Sauveur": 8.5,
    "Assomption": 8.5,
    "Benny": 8,
    "Dorval": 8,
    "Magog": 9.5,
    "Berthierville": 9.5
}


days_dict = {
    0: "Monday",
    1: "Tuesday",
    2: "Wenesday",
    3: "Thursday",
    4: "Friday",
    5: "Saturday",
    6: "Sunday"
}

# Weather: 
# Rain or Snow  = 0
# Clouds + Wind = 1
# Clouds        = 2
# Blue sky      = 3

weather_dict = {
    0: "Rain or Snow",
    1: "Windy or heavily cloudy",
    2: "cloudy",
    3: "Blue sky"
}

# %%
# INPUTS_COLS = ["weather", "temperature", "traffic_time", "weekday", "park_score"]

# Test 1:
input_test = [ 0, 1.0, 20, 6, 8]


input_test_array = np.array([input_test]) 

prediction = model.predict(input_test_array)
print(prediction)



# Test 2:
input_test = [ 3.0, 23.0, 20, 6, 9]


input_test_array = np.array([input_test]) 

prediction = model.predict(input_test_array)
print(prediction)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# [[1.3750858]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# [[3.0704615]]

# %% [markdown]
# ## Intepretation:

# %% [markdown]
# #### Test1:
# a rainy day, a skatepark graded 8/10 gets a 1.37/10, COHERENT because nobody want to skate in the rin or snow...
#
# #### Test2:
# Sky is blue, the skatepark is graded 9/10,    3.07/10, the grade is very low... INCOHERENT
