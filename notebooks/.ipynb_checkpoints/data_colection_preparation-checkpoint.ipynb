# %% [markdown]
# ##Collection:##

# %% [markdown]
# Import and data:

# %%
! pip install pandas
! pip install tqdm
! pip install numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in c:\users\doyez\appdata\roaming\python\python313\site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\doyez\appdata\roaming\python\python313\site-packages (from pandas) (2.3.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\doyez\appdata\roaming\python\python313\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\doyez\appdata\roaming\python\python313\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\doyez\appdata\roaming\python\python313\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\doyez\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: C:\Python313\python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tqdm in c:\users\doyez\appdata\roaming\python\python313\site-packages (4.67.1)
# Requirement already satisfied: colorama in c:\users\doyez\appdata\roaming\python\python313\site-packages (from tqdm) (0.4.6)
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: C:\Python313\python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in c:\users\doyez\appdata\roaming\python\python313\site-packages (2.3.4)
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: C:\Python313\python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import tqdm
import numpy as np
import random
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pandas as pd
#       2 import tqdm
#       3 import numpy as np
#
# ModuleNotFoundError: No module named 'pandas'

# %%
skateparks_dict = {
    "Ahuntsic": 8,
    "VanHorne": 4,
    "Verdun": 2,
    "Lasalle": 8.5,
    "Préfontaine": 8.5,
    "Boucherville": 7,
    "Taz": 7,
    "Spin": 6.5,
    "Saint Jérome": 8,
    "Saint Sauveur": 8.5,
    "Assomption": 8.5,
    "Benny": 8,
    "Dorval": 8,
    "Magog": 9.5,
    "Berthierville": 9.5
}


days_dict = {
    0: "Monday",
    1: "Tuesday",
    2: "Wenesday",
    3: "Thursday",
    4: "Friday",
    5: "Saturday",
    6: "Sunday"
}

# Weather: 
# Rain or Snow  = 0
# Clouds + Wind = 1
# Clouds        = 2
# Blue sky      = 3

weather_dict = {
    0: "Rain or Snow",
    1: "Windy or heavily cloudy",
    2: "cloudy",
    3: "Blue sky"
}

# %% [markdown]
# Temperature will be in °C
# traffic time: in minutes
# weekday 0: Monday -> 6: Sunday

# %%
N=  20
data = []

for idx in tqdm.tqdm(range(N)):
    try:
        weather = random.randint(0, 3)
        temperature = np.clip(np.random.normal(22,6), -5, 38)
        traffic_time = np.clip(np.random.normal(25, 10), 5, 150)
        weekday = random.randint(0, 6)

        print(f"\n\nJour: {days_dict[weekday]}\t météo: {weather_dict[weather]}, a {temperature}°C\t, temps de traffic: {traffic_time}min")
        for idx, (spot_name, note) in enumerate(skateparks_dict.items()):
            print(f"{spot_name} (note: {note}/10)")
            satisfaction = input(f"Satisfaction?")
            data.append({
                "spot_name": spot_name,
                "index spot": idx,
                "weather": weather_dict,
                "temperature": round(float(temperature), 1),
                "traffic_time": round(float(traffic_time), 1),
                "weekday": weekday,
                "park_score": note,
                "satisfaction": round(float(satisfaction), 2)
            })
    except Exception as e:
        print(e)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 N=  20
#       2 data = []
# ----> 4 for idx in tqdm.tqdm(range(N)):
#       5     try:
#       6         weather = random.randint(0, 3)
#
# NameError: name 'tqdm' is not defined
