# %% [markdown]
# ## Create a Model to find the best spot for my skate session

# %% [markdown]
# My goal for this project is to build the best machine learning model to help me find the best skatepark for my session, according of the week day, the weather, temperature and the traffic time.
# Montréal has 14 skateparks, sometimes it's hard for me to choose the best spot.
# The input will be:
#  -  the weather (of course, I don't want to skate outside if it snows...)
#  -  the temperature
#  -  the traffic time (Sometimes the traffic at Montréal is a nightmare)
#  - I also gave a general grade for the skatepark..
#
# ## Connexion to the S3 bucket and get the data:

# %%
import os, boto3, random, datetime
import pandas as pd
from botocore.exceptions import ClientError
from io import StringIO
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, models
# Out:
# 2025-11-16 01:57:41.179013: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-16 01:57:41.200748: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-16 01:57:41.887634: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-16 01:57:44.641089: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-16 01:57:44.644697: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.

# %%
# %load_ext tensorboard
! rm -rf ./logs/

# %% [markdown]
# ## Get Data from S3:

# %% [markdown]
# For the model, as it's a simple regression, we can just give as a input 1 spot index, and not the 14 skatespots.
# The time to do all the inference will not be a problem, it's not a critical system.
# It will be easier to me to add skateparks, Montreal build new one, in the future.

# %%
s3 = boto3.client(
    "s3",
    endpoint_url=os.getenv("S3_ENDPOINT"),
    aws_access_key_id=os.getenv("AWS_ACCESS_KEY_ID"),
    aws_secret_access_key=os.getenv("AWS_SECRET_ACCESS_KEY"),
    region_name="us-east-1"
)

# %%
BUCKET_NAME = "skatedata"         
FILE_KEY = "cleaned_skatepark_dataset.csv"  

obj = s3.get_object(Bucket=BUCKET_NAME, Key=FILE_KEY)
df = pd.read_csv(StringIO(obj['Body'].read().decode('utf-8')))

print(df.head())
# Out:
#      spot_name  index spot  weather  temperature  traffic_time  satisfaction
# 0     Ahuntsic           0        2         28.6          23.7           6.0
# 1     VanHorne           1        2         28.6          23.7           5.0
# 2       Verdun           2        2         28.6          23.7           3.0
# 3      Lasalle           3        2         28.6          23.7           6.0
# 4  Préfontaine           4        2         28.6          23.7           5.0

# %% [markdown]
# ## Generator:

# %%
random.seed(1)

INPUTS_COLS = ["index spot", "weather", "temperature", "traffic_time"]
OUTPUT_COLS =  "satisfaction"
TRAINING_PERCENTAGE = 85



dataset = [
                [row[INPUTS_COLS].tolist(), row[OUTPUT_COLS]]
                for _, row in df.iterrows()
            ]
random.shuffle(dataset)

split_idx = int(TRAINING_PERCENTAGE / 100 * len(dataset))
train_dataset = dataset[:split_idx]
val_dataset = dataset[split_idx:]


import numpy as np

def generator(part_dataset, batch_size=4):
    X_batch, y_batch = [], []

    while True:
        for X, y in part_dataset:
            X_batch.append(X)
            y_batch.append(y)

            if len(X_batch) == batch_size:
                yield np.array(X_batch, dtype=np.float32), np.array(y_batch, dtype=np.float32)
                X_batch, y_batch = [], []

        if X_batch:
            yield np.array(X_batch, dtype=np.float32), np.array(y_batch, dtype=np.float32)
            X_batch, y_batch = [], []

# %% [markdown]
# ## Model Architecture:

# %% [markdown]
# First Model tested will be 5 Dense Layers.

# %%
INPUT_DIM = len(INPUTS_COLS)
OUTPUT_DIM = 1

model = models.Sequential([
    layers.Input(shape = (INPUT_DIM,)),
    layers.Dense(64, activation='relu'),
    layers.Dense(64, activation='relu'),
    layers.Dense(32, activation='relu'),
    layers.Dense(OUTPUT_DIM, activation='linear')
])

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=5e-6),
    loss='mse',            
    metrics=['mae']        
)

model.summary()
# Out:
# 2025-11-16 01:57:56.146584: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,593 (25.75 KB)
#  Trainable params: 6,593 (25.75 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Training:

# %%
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

# %%
# Epoch 479/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 10.1501 - mae: 2.8823 - val_loss: 9.3276 - val_mae: 2.7831
# Epoch 480/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 9.8839 - mae: 2.8483 - val_loss: 9.3251 - val_mae: 2.7829
# Epoch 481/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 9.4631 - mae: 2.7864 - val_loss: 9.3224 - val_mae: 2.7827
# Epoch 482/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 9.8007 - mae: 2.8338 - val_loss: 9.3196 - val_mae: 2.7824
# Epoch 483/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 9.3583 - mae: 2.7656 - val_loss: 9.3169 - val_mae: 2.7821
# Epoch 484/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 10.0275 - mae: 2.8736 - val_loss: 9.3142 - val_mae: 2.7818
# Epoch 485/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 9.6119 - mae: 2.8112 - val_loss: 9.3114 - val_mae: 2.7814
# Epoch 486/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 10.1367 - mae: 2.8823 - val_loss: 9.3088 - val_mae: 2.7811
# Epoch 487/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 9.7421 - mae: 2.8326 - val_loss: 9.3062 - val_mae: 2.7809
# Epoch 488/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 10.1355 - mae: 2.8805 - val_loss: 9.3036 - val_mae: 2.7806
# Epoch 489/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 9.8698 - mae: 2.8465 - val_loss: 9.3011 - val_mae: 2.7804
# Epoch 490/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 9.4508 - mae: 2.7847 - val_loss: 9.2985 - val_mae: 2.7802
# Epoch 491/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 9.7852 - mae: 2.8318 - val_loss: 9.2958 - val_mae: 2.7799
# Epoch 492/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 9.3445 - mae: 2.7639 - val_loss: 9.2931 - val_mae: 2.7796
# Epoch 493/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 10.0148 - mae: 2.8721 - val_loss: 9.2905 - val_mae: 2.7793
# Epoch 494/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 9.5967 - mae: 2.8093 - val_loss: 9.2878 - val_mae: 2.7790
# Epoch 495/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 10.1235 - mae: 2.8807 - val_loss: 9.2852 - val_mae: 2.7787
# Epoch 496/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 9.7282 - mae: 2.8309 - val_loss: 9.2827 - val_mae: 2.7784
# Epoch 497/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 10.1212 - mae: 2.8787 - val_loss: 9.2802 - val_mae: 2.7782
# Epoch 498/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 9.8558 - mae: 2.8446 - val_loss: 9.2778 - val_mae: 2.7780
# Epoch 499/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 9.4388 - mae: 2.7831 - val_loss: 9.2752 - val_mae: 2.7778
# Epoch 500/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 9.7701 - mae: 2.8299 - val_loss: 9.2725 - val_mae: 2.7775

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

mae = history.history.get('mae')
val_mae = history.history.get('val_mae')

epochs = range(1, EPOCHS + 1)

plt.figure(figsize = (12,5))
plt.subplot(1,2,1)
plt.plot(epochs, loss, 'bo-', label = "Training loss")
plt.plot(epochs, val_loss, 'ro-', label = "Val loss")

plt.title("Loss evolution")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()

plt.subplot(1,2,2)
plt.plot(epochs, mae, 'bo-', label='Training mae')
plt.plot(epochs, val_mae, 'ro-', label="Validation mae")
plt.title( "mae evolution")
plt.xlabel('Epochs')
plt.ylabel("mae")
plt.legend()
plt.show()

# %%
# %tensorboard --logdir logs/fit
# Out:
# Reusing TensorBoard on port 6006 (pid 64727), started 8 days, 22:43:47 ago. (Use '!kill 64727' to kill it.)
#       <iframe id="tensorboard-frame-1d43d1ffecd1345e" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-1d43d1ffecd1345e");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# ## Test and Validation:

# %%
skateparks_list = [
    "Ahuntsic"         , # 0
    "VanHorne"         , # 1
    "Verdun"           , # 2
    "Lasalle"          , # 3
    "Préfontaine"      , # 4
    "Boucherville"     , # 5
    "Taz"              , # 6
    "Spin"             , # 7
    "Saint Jérome"     , # 8
    "Saint Sauveur"    , # 9
    "Assomption"       , # 10
    "Benny"            , # 11
    "Dorval"           , # 12
    "Magog"            , # 13
    "Berthierville"      # 14
]

# Weather: 
# Rain or Snow  = 0
# Clouds + Wind = 1
# Clouds        = 2
# Blue sky      = 3

weather_dict = {
    0: "Rain or Snow",
    1: "Windy or heavily cloudy",
    2: "cloudy",
    3: "Blue sky"
}

# %% [markdown]
# ## Test1:
# Sky is blue, Temperature is great, 24°C.
# Everyone want to go outside. As a rare weather here in canada, or maybe it's a great day in spring, I would go outside of the city.
# The Best grade should be for Magog, Berthierville, St Jerome, st Sauveur
# The Worst should be Taz and Spin

# %%
import numpy as np


WEATHER = 3        # Sky blue
TEMP = 24.0        # great temperature 24 °C
BATCH_INPUTS = [
    28, 24, 30, 35, 15, 20, 34, 40, 50, 60, 45, 30, 30, 120, 60
]

predictions = []

for idx, traffic_time in enumerate(BATCH_INPUTS):
    input_test = [idx, WEATHER, TEMP, traffic_time]
    input_test_array = np.array([input_test])

    prediction = model.predict(input_test_array, verbose=0)[0][0]
    predictions.append((skateparks_list[idx], float(prediction)))

predictions_sorted = sorted(predictions, key=lambda x: x[1], reverse=True)

for rank, (spot, grade) in enumerate(predictions_sorted, start=1):
    print(f"{rank:2d}. {spot:<20s} → {grade:.2f}/10")
# Out:
#  1. Magog                → 11.41/10
#  2. Saint Sauveur        → 6.87/10
#  3. Berthierville        → 6.55/10
#  4. Saint Jérome         → 5.97/10
#  5. Assomption           → 5.38/10
#  6. Spin                 → 4.99/10
#  7. Lasalle              → 4.62/10
#  8. Taz                  → 4.47/10
#  9. Benny                → 4.23/10
# 10. Verdun               → 4.21/10
# 11. Dorval               → 4.21/10
# 12. Ahuntsic             → 4.06/10
# 13. VanHorne             → 3.93/10
# 14. Boucherville         → 3.84/10
# 15. Préfontaine          → 3.48/10

# %% [markdown]
# ## Test2:
#
# Weather is really bad, snow and 0°C...
# Everyone is at the taz or Spin.
# Nobody will skate outside...

# %%
import numpy as np


WEATHER = 0        # Sky blue
TEMP = 0.0        # great temperature 24 °C
BATCH_INPUTS = [
    28, 24, 30, 35, 15, 20, 34, 40, 50, 60, 45, 30, 30, 120, 60
]

predictions = []

for idx, traffic_time in enumerate(BATCH_INPUTS):
    input_test = [idx, WEATHER, TEMP, traffic_time]
    input_test_array = np.array([input_test])

    prediction = model.predict(input_test_array, verbose=0)[0][0]
    predictions.append((skateparks_list[idx], float(prediction)))

predictions_sorted = sorted(predictions, key=lambda x: x[1], reverse=True)

for rank, (spot, grade) in enumerate(predictions_sorted, start=1):
    print(f"{rank:2d}. {spot:<20s} → {grade:.2f}/10")
# Out:
#  1. Magog                → 9.60/10
#  2. Saint Sauveur        → 4.70/10
#  3. Berthierville        → 4.34/10
#  4. Saint Jérome         → 3.90/10
#  5. Assomption           → 3.30/10
#  6. Spin                 → 3.11/10
#  7. Lasalle              → 2.86/10
#  8. Taz                  → 2.64/10
#  9. Verdun               → 2.47/10
# 10. Ahuntsic             → 2.44/10
# 11. VanHorne             → 2.01/10
# 12. Benny                → 1.96/10
# 13. Dorval               → 1.88/10
# 14. Boucherville         → 1.45/10
# 15. Préfontaine          → 1.08/10

# %% [markdown]
# ## Intepretation:

# %% [markdown]
# #### Test1:
# A beautiful day, we want to go outside of the city. Coherent!
# #### Test2:
# Even if the good skatepark, outside of the city still get good grade, it should be the indoor skatepark the winner..

# %% [markdown]
# ## Tensorflow Lite:

# %%
try:
    converter = tf.lite.TFLiteConverter.from_keras_model(model)
    converter.optimizations = [tf.lite.Optimize.DEFAULT]
    tflite_model = converter.convert()

    with open("model.tflite", 'wb') as file:
        file.write(tflite_model)
    print("[+] Great success!!!!")
except Exception as e:
    print(f"[-] {e}")
